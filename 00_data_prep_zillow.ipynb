# %%
# Import base Libraries
import pandas as pd
# import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# add the scripts directory to the python path,
# or the set of places the python interpreter looks for code files
import sys
sys.path.insert(0, './ds_helpers')

# now read in the functions
from helpers import read_in_dataset, merge_dataset

# %% [markdown]
# ### Import Data

# %%
# Set path to dataset
dataset_folder = '../datasets/zillow/'

# %%
# List files in dataset
# !ls ../datasets/zillow/
# Out:
# properties_2016.csv
# properties_2017.csv
# sample_submission.csv
# train_2016.csv
# train_2017.csv
# zillow_data_dictionary.xlsx

# %%
# import Data Dictionary for terms
data_dictionary = pd.read_excel(f'{dataset_folder}/zillow_data_dictionary.xlsx')
data_dictionary.head()
# Out:
#                       Feature  \
# 0     'airconditioningtypeid'
# 1  'architecturalstyletypeid'
# 2              'basementsqft'
# 3               'bathroomcnt'
# 4                'bedroomcnt'
#
#                                          Description
# 0   Type of cooling system present in the home (i...
# 1   Architectural style of the home (i.e. ranch, ...
# 2   Finished living area below or partially below...
# 3   Number of bathrooms in home including fractio...
# 4                        Number of bedrooms in home

# %%
properties = read_in_dataset(dataset_folder,"properties_2016.csv",True)
# Out:
# ------------------------------------------
#
# Reading in the properties_2016.csv dataset:
#
# ------------------------------------------
#
# it has 2985217 rows and 58 columns
#
# ------------------------------------------
#
# It has the following columns:
#
# Index(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
# ...

# %%
raw_train = read_in_dataset(dataset_folder,"train_2016.csv",True)
# Out:
# ------------------------------------------
#
# Reading in the train_2016.csv dataset:
#
# ------------------------------------------
#
# it has 90275 rows and 3 columns
#
# ------------------------------------------
#
# It has the following columns:
#
# Index(['parcelid', 'logerror', 'transactiondate'], dtype='object')
#
# ------------------------------------------
#
#  The first 5 rows look like this:
#
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02
#
# ------------------------------------------
#
#            parcelid      logerror
# count  9.027500e+04  90275.000000
# mean   1.298466e+07      0.011457
# std    2.504510e+06      0.161079
# min    1.071174e+07     -4.605000
# 25%    1.155950e+07     -0.025300
# 50%    1.254734e+07      0.006000
# 75%    1.422755e+07      0.039200
# ...

# %%
# how many train records don't have a matching property
len(set(raw_train.parcelid) - set(properties.parcelid))
# Out:
# 0

# %%
# how many properties don't have a matching train record
len(set(properties.parcelid) - set(raw_train.parcelid))
# Out:
# 2895067

# %%
# If you want to see function inline in notebook
# import inspect
# # inspect the function we made for this
# print(inspect.getsource(merge_dataset))

# Or use:
# read_in_dataset??

# %%
# merge the data and remove the raw datasets
train_data_merged = merge_dataset(raw_train, properties, 'parcelid')
del raw_train
del properties

# %%
train_data_merged.head()
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  \
# 0  11016594    0.0276      2016-01-01                    1.0
# 1  14366692   -0.1684      2016-01-01                    NaN
# 2  12098116   -0.0040      2016-01-01                    1.0
# 3  12643413    0.0218      2016-01-02                    1.0
# 4  14432541   -0.0050      2016-01-02                    NaN
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       NaN           NaN          2.0         3.0
# 1                       NaN           NaN          3.5         4.0
# 2                       NaN           NaN          3.0         2.0
# 3                       NaN           NaN          2.0         2.0
# 4                       NaN           NaN          2.5         4.0
#
#    buildingclasstypeid  buildingqualitytypeid  ...  numberofstories  \
# 0                  NaN                    4.0  ...              NaN
# ...

# %%
# write out the training data to csv so we can load it into the next notebook
train_data_merged.to_csv(f'derived_data/train_data_merged_2016.csv', index=False)
